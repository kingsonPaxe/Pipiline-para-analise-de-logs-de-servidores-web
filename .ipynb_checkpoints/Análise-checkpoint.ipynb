# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('logdw.csv')

# %%
df = df.rename(columns={
    'Ip'                : 'Ip',
    'Date'              : 'Data',
    'Methode'           : 'Metodo',
    'URL'               : 'URL',
    'Protocol'          : 'Protocolo',
    'status_code'       : 'Codigo_Status',
    'is_mobile'         : 'E_Mobile',
    'is_tablet'         : 'E_Tablet',
    'is_pc'             : 'E_Pc',
    'is_bot'            : 'E_Bot',
    'browser'           : 'Navegador',
    'os'                : 'Sistema_Operacional',
    'status'            : 'Status',
    'continent'         : 'Continente',
    'country'           : 'Pais',
    'countryCode'       : 'Codigo_Pais',
    'regionName'        : 'Regiao',
    'city'              : 'Cidade',
    'lat'               : 'Latitude',
    'lon'               : 'Longitude',
    'isp'               : 'Isp',
    'org'               : 'Organizacao',
    'as'                : 'As',
    'proxy'             : 'Proxy',
    'hosting'           : 'Hospedagem',
    'query'             : 'Consulta'
})

# %%
df.head()
# Out:
#    Unnamed: 0             Ip                 Data Metodo  \
# 0           0   54.36.149.41  2019-01-22 03:56:14    GET
# 1           1  40.77.167.129  2019-01-22 03:56:17    GET
# 2           2    91.99.72.15  2019-01-22 03:56:17    GET
# 3           3  40.77.167.129  2019-01-22 03:56:17    GET
# 4           4  40.77.167.129  2019-01-22 03:56:18    GET
#
#                                                  URL Protocolo  Status  \
# 0  /filter/27-13-%D9%85%DA%AF%D8%A7%D9%BE%DB%8C%D...  HTTP/1.1     200
# 1                  /image/14925/productmodel/100x100  HTTP/1.1     200
# 2  /product/31893/62100/%D8%B3%D8%B4%D9%88%D8%A7%...  HTTP/1.1     200
# 3                  /image/23488/productmodel/150x150  HTTP/1.1     200
# 4                  /image/45437/productmodel/150x150  HTTP/1.1     200
#
#    E_Mobile  E_Tablet   E_Pc  E_Bot  Navegador Sistema_Operacional   Status  \
# 0     False     False  False   True  AhrefsBot               Other  success
# 1     False     False  False   True    bingbot               Other  success
# 2     False     False   True  False    Firefox             Windows  success
# 3     False     False  False   True    bingbot               Other  success
# 4     False     False  False   True    bingbot               Other  success
#
#       Continente           Pais Codigo_Pais           Regiao     Cidade  \
# 0         Europe         France          FR  Hauts-de-France    Roubaix
# 1  North America  United States          US         Virginia    Boydton
# 2         Europe        Germany          DE          Bavaria  Nuremberg
# 3  North America  United States          US         Virginia    Boydton
# 4  North America  United States          US         Virginia    Boydton
#
#     Latitude  Longitude                    Isp  \
# 0  50.692400    3.20113                OVH SAS
# 1  36.677696  -78.37471  Microsoft Corporation
# 2  49.452700   11.07830    Hetzner Online GmbH
# 3  36.677696  -78.37471  Microsoft Corporation
# 4  36.677696  -78.37471  Microsoft Corporation
#
#                        Organizacao                            As  Proxy  \
# 0                              OVH               AS16276 OVH SAS  False
# 1  Microsoft Azure Cloud (eastus2)  AS8075 Microsoft Corporation  False
# 2                          Hetzner   AS24940 Hetzner Online GmbH  False
# 3  Microsoft Azure Cloud (eastus2)  AS8075 Microsoft Corporation  False
# 4  Microsoft Azure Cloud (eastus2)  AS8075 Microsoft Corporation  False
#
#    Hospedagem       Consulta
# 0        True   54.36.149.41
# 1        True  40.77.167.129
# 2        True    91.99.72.15
# 3        True  40.77.167.129
# 4        True  40.77.167.129

# %%
df = df.astype({
    # Texto
    'Ip'                  : 'string',
    'Metodo'              : 'string',
    'URL'                 : 'string',
    'Protocolo'           : 'string',
    'Navegador'           : 'string',
    'Sistema_Operacional' : 'string',
    'Continente'          : 'string',
    'Pais'                : 'string',    
    'Regiao'              : 'string',
    'Cidade'              : 'string',
    'Isp'                 : 'string',
    'Organizacao'         : 'string',
    'As'                  : 'string',
    'Consulta'            : 'string',

    # Numérico
    'Status'       : 'int',
    'Latitude'            : 'float32',
    'Longitude'           : 'float32',

    # Booleano
    'E_Mobile'            : 'bool',
    'E_Tablet'            : 'bool',
    'E_Pc'                : 'bool',
    'E_Bot'               : 'bool',
    'Proxy'               : 'bool',
    'Hospedagem'          : 'bool',
    'Status'              : 'bool',
})

# Data separado pois requer o pd.to_datetime
df['Data'] = pd.to_datetime(df['Data'])

# %%
pd.set_option('display.max_columns', None) # maximo de colunas

# %%
df.drop(columns='Unnamed: 0', inplace = True, errors='ignore')

# %%
df.head()
# Out:
#               Ip                Data Metodo  \
# 0   54.36.149.41 2019-01-22 03:56:14    GET
# 1  40.77.167.129 2019-01-22 03:56:17    GET
# 2    91.99.72.15 2019-01-22 03:56:17    GET
# 3  40.77.167.129 2019-01-22 03:56:17    GET
# 4  40.77.167.129 2019-01-22 03:56:18    GET
#
#                                                  URL Protocolo  Status  \
# 0  /filter/27-13-%D9%85%DA%AF%D8%A7%D9%BE%DB%8C%D...  HTTP/1.1    True
# 1                  /image/14925/productmodel/100x100  HTTP/1.1    True
# 2  /product/31893/62100/%D8%B3%D8%B4%D9%88%D8%A7%...  HTTP/1.1    True
# 3                  /image/23488/productmodel/150x150  HTTP/1.1    True
# 4                  /image/45437/productmodel/150x150  HTTP/1.1    True
#
#    E_Mobile  E_Tablet   E_Pc  E_Bot  Navegador Sistema_Operacional  Status  \
# 0     False     False  False   True  AhrefsBot               Other    True
# 1     False     False  False   True    bingbot               Other    True
# 2     False     False   True  False    Firefox             Windows    True
# 3     False     False  False   True    bingbot               Other    True
# 4     False     False  False   True    bingbot               Other    True
#
#       Continente           Pais Codigo_Pais           Regiao     Cidade  \
# 0         Europe         France          FR  Hauts-de-France    Roubaix
# 1  North America  United States          US         Virginia    Boydton
# 2         Europe        Germany          DE          Bavaria  Nuremberg
# 3  North America  United States          US         Virginia    Boydton
# 4  North America  United States          US         Virginia    Boydton
#
#     Latitude  Longitude                    Isp  \
# 0  50.692402    3.20113                OVH SAS
# 1  36.677696  -78.37471  Microsoft Corporation
# 2  49.452702   11.07830    Hetzner Online GmbH
# 3  36.677696  -78.37471  Microsoft Corporation
# 4  36.677696  -78.37471  Microsoft Corporation
#
#                        Organizacao                            As  Proxy  \
# 0                              OVH               AS16276 OVH SAS  False
# 1  Microsoft Azure Cloud (eastus2)  AS8075 Microsoft Corporation  False
# 2                          Hetzner   AS24940 Hetzner Online GmbH  False
# 3  Microsoft Azure Cloud (eastus2)  AS8075 Microsoft Corporation  False
# 4  Microsoft Azure Cloud (eastus2)  AS8075 Microsoft Corporation  False
#
#    Hospedagem       Consulta
# 0        True   54.36.149.41
# 1        True  40.77.167.129
# 2        True    91.99.72.15
# 3        True  40.77.167.129
# 4        True  40.77.167.129

# %% [markdown]
# ## Informação sobre o dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39685 entries, 0 to 39684
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ip                   39685 non-null  string
#  1   Data                 39685 non-null  datetime64[us]
#  2   Metodo               39685 non-null  string
#  3   URL                  39287 non-null  string
#  4   Protocolo            39685 non-null  string
#  5   Status               39685 non-null  bool
#  6   E_Mobile             39685 non-null  bool
#  7   E_Tablet             39685 non-null  bool
#  8   E_Pc                 39685 non-null  bool
#  9   E_Bot                39685 non-null  bool
#  10  Navegador            39685 non-null  string
#  11  Sistema_Operacional  39685 non-null  string
#  12  Status               39685 non-null  bool
#  13  Continente           39685 non-null  string
#  14  Pais                 39685 non-null  string
#  15  Codigo_Pais          39685 non-null  str
#  16  Regiao               39685 non-null  string
#  17  Cidade               39685 non-null  string
#  18  Latitude             39685 non-null  float32
#  19  Longitude            39685 non-null  float32
#  20  Isp                  39685 non-null  string
#  21  Organizacao          37329 non-null  string
#  22  As                   39487 non-null  string
#  23  Proxy                39685 non-null  bool
#  24  Hospedagem           39685 non-null  bool
#  25  Consulta             39685 non-null  string
# dtypes: bool(8), datetime64[us](1), float32(2), str(1), string(14)
# memory usage: 5.5 MB

# %% [markdown]
# # ---------- KPIs Principais -------------------
# - Total de reuisições
# - Ips únicos
# - Taxa de erros (4xx/5xx)
# - URL mais visitada

# %%
# --- KPIs Principais ---

#total de requesições
total = df.URL.value_counts().sum()
print(f'Total de requesições: {total:,}')
# verificar o total de ips unicos
ips_unicos = df.Ip.nunique() 
print(f'Total de ips unicos: {ips_unicos}')

# url mais 
s_a = df.URL.groupby(df.URL).count().sort_values(ascending=False)
print(f'O url mais visitado: {s_a.keys()[0]}')

#Taxa de erros(4xx/5xx)
total_req = len(df)
erros_req = len(df[df.Status  >= 400])
error_rate = (erros_req / total_req) * 100 if total_req > 0 else 0
print(f"Taxa de Erros (4xx/5xx): {error_rate:.2f}%")
# Out:
# Total de requesições: 39,287
# Total de ips unicos: 2619
# O url mais visitado: /filter
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 16
#      14 #Taxa de erros(4xx/5xx)
#      15 total_req = len(df)
# ---> 16 erros_req = len(df[df.Status  >= 400])
#      17 error_rate = (erros_req / total_req) * 100 if total_req > 0 else 0
#      18 print(f"Taxa de Erros (4xx/5xx): {error_rate:.2f}%")
#
# File ~/Documents/Meu Proprio Estagio/Analise de Logs de um servidor web/env/lib64/python3.14/site-packages/pandas/core/frame.py:4365, in DataFrame.__getitem__(self, key)
#    4363 # Do we have a (boolean) DataFrame?
#    4364 if isinstance(key, DataFrame):
# -> 4365     return self.where(key)
#    4367 # Do we have a (boolean) 1d indexer?
#    4368 if com.is_bool_indexer(key):
#
# File ~/Documents/Meu Proprio Estagio/Analise de Logs de um servidor web/env/lib64/python3.14/site-packages/pandas/core/generic.py:10321, in NDFrame.where(self, cond, other, inplace, axis, level)
#   10314             warnings.warn(
#   10315                 _chained_assignment_method_msg,
#   10316                 ChainedAssignmentError,
#   10317                 stacklevel=2,
#   10318             )
#   10320 other = common.apply_if_callable(other, self)
# > 10321 return self._where(cond, other, inplace=inplace, axis=axis, level=level)
#
# File ~/Documents/Meu Proprio Estagio/Analise de Logs de um servidor web/env/lib64/python3.14/site-packages/pandas/core/generic.py:10045, in NDFrame._where(self, cond, other, inplace, axis, level)
#   10042     cond = cond.astype(bool)
#   10044 cond = -cond if inplace else cond
# > 10045 cond = cond.reindex(self._info_axis, axis=self._info_axis_number)
#   10047 # try to align with other
#   10048 if isinstance(other, NDFrame):
#   10049     # align with me
#
# File ~/Documents/Meu Proprio Estagio/Analise de Logs de um servidor web/env/lib64/python3.14/site-packages/pandas/core/frame.py:6078, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5843 def reindex(
#    5844     self,
#    5845     labels=None,
#    (...)   5855     tolerance=None,
#    5856 ) -> DataFrame:
#    5857     """
#    5858     Conform DataFrame to new index with optional filling logic.
#    5859
#    (...)   6076     See the :ref:`user guide <basics.reindexing>` for more.
#    6077     """
# -> 6078     return super().reindex(
#    6079         labels=labels,
#    6080         index=index,
#    6081         columns=columns,
#    6082         axis=axis,
#    6083         method=method,
#    6084         level=level,
#    6085         fill_value=fill_value,
#    6086         limit=limit,
#    6087         tolerance=tolerance,
#    6088         copy=copy,
#    6089     )
#
# File ~/Documents/Meu Proprio Estagio/Analise de Logs de um servidor web/env/lib64/python3.14/site-packages/pandas/core/generic.py:5476, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5473     return self._reindex_multi(axes, fill_value)
#    5475 # perform the reindex on the axes
# -> 5476 return self._reindex_axes(
#    5477     axes, level, limit, tolerance, method, fill_value
#    5478 ).__finalize__(self, method="reindex")
#
# File ~/Documents/Meu Proprio Estagio/Analise de Logs de um servidor web/env/lib64/python3.14/site-packages/pandas/core/generic.py:5498, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value)
#    5495     continue
#    5497 ax = self._get_axis(a)
# -> 5498 new_index, indexer = ax.reindex(
#    5499     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5500 )
#    5502 axis = self._get_axis_number(a)
#    5503 obj = obj._reindex_with_indexers(
#    5504     {axis: [new_index, indexer]},
#    5505     fill_value=fill_value,
#    5506     allow_dups=False,
#    5507 )
#
# File ~/Documents/Meu Proprio Estagio/Analise de Logs de um servidor web/env/lib64/python3.14/site-packages/pandas/core/indexes/base.py:4253, in Index.reindex(self, target, method, level, limit, tolerance)
#    4250     raise ValueError("cannot handle a non-unique multi-index!")
#    4251 elif not self.is_unique:
#    4252     # GH#42568
# -> 4253     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4254 else:
#    4255     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %% [markdown]
# Formula da taxa de erro:
# $Taxa deerro = (Número de Erros/Total de tentativas) * 100%% $

# %% [markdown]
# #  Passo1 : ver recursos mais acessados

# %%
# Analise 1: recursos mais acessados
# top 10
recursos_mais_acess = df.URL.groupby(df.URL).count().sort_values(ascending=False).reset_index(name = 'Numero de vezes que foi acessado')[:10]
recursos_mais_acess
# Out:
#                                 URL  Numero de vezes que foi acessado
# 0                           /filter                              1366
# 1  /static/css/font/wyekan/fontwoff                              1208
# 2                      /image/33888                               879
# 3                      /image/11947                               698
# 4                       /faviconico                               323
# 5                /customer/register                               252
# 6                         /m/filter                               242
# 7                      /image/11926                               217
# 8                      /image/27142                               184
# 9                      /image/11911                               124

# %%
# Mostrando graficamente
fig = px.bar(data_frame= recursos_mais_acess, y = 'URL', x = 'Numero de vezes que foi acessado',title = 'Top 10 dos Recursos mais acessados', color = 'URL')
fig.update_yaxes(
    categoryorder="total ascending"
)
fig.show()

# %% [markdown]
# # Passo2: destribuição de StatusCode

# %%
df.rename(columns = {'Status': 'status_code'}, inplace = True)

# %%
code = df.status_code.groupby(df.status_code).count().sort_index().reset_index(name = 'Quantidade')
code
# Out:
#     status_code  Quantidade
# 0           200       34080
# 1           301        1063
# 2           302        2237
# 3           304        1031
# 4           400           6
# 5           403          32
# 6           404        1213
# 7           499          16
# 8           500           1
# 9           502           5
# 10          504           1

# %%
# # destribuição de estatus
statusCode = df['status_code'].value_counts().reset_index()
statusCode.columns = ['Status', 'Quantidade']

px.pie(statusCode, values = 'Quantidade', names = 'Status', title='Destribução de Status code', hole = 0.4)

# %% [markdown]
# # Passo3: Ver os horários de pico de acesso

# %%
df.columns
# Out:
# Index(['Ip', 'Date', 'Methode', 'URL', 'Protocol', 'status_code', 'is_mobile',
#        'is_tablet', 'is_pc', 'is_bot', 'browser', 'os', 'status', 'continent',
#        'country', 'countryCode', 'regionName', 'city', 'lat', 'lon', 'isp',
#        'org', 'as', 'proxy', 'hosting', 'query'],
#       dtype='object')

# %%
df.Data = pd.to_datetime(df.Data) # fromatando o tempo
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_208756/2082566729.py in ?()
# ----> 1 df.Data = pd.to_datetime(df.Data) # fromatando o tempo
#
# ~/.local/lib/python3.14/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Data'

# %%
df.Data = df.Data.dt.tz_localize(None) # type:ignore isso é para normalizar o fusohorario, ou seja, remover.

# %%
#acahar os horários de pico de acesso
df['hora'] = df.Data.dt.hour

# %%
horaios_picos = df.hora.value_counts().reset_index(name = 'Total de acessos')
horaios_picos
# Out:
#    hora  Total de acessos
# 0     4               850
# 1     3               638

# %%
df["dia_semana"] = df["Data"].dt.day_name()
df.dia_semana = 'Terça-feira' # padronizando...como todas as requisições foram feitas na terça então troque a palavra que estava em ingles para portugues
print(f'Os horarios de picos acessos vão de 0{horaios_picos.hora[0]}-0{horaios_picos.hora[1]}h. Todas foram feitas na {df.dia_semana[0]}' )
fig = px.bar(data_frame=horaios_picos, x = 'hora', y = 'Total de acessos', color = 'hora', title = 'Horarios de Pico de acessos na Terça-feria')
fig.show()
# Out:
# Os horarios de picos acessos vão de 04-03h. Todas foram feitas na Terça-feira

# %%
hora_picos = df.Data.dt.floor('h').value_counts().reset_index(name = 'Requesições')
# hora_picos
px.line(data_frame = hora_picos, x="Data", y="Requesições",title='Volume de Requisições por Hora',markers=True)

# %% [markdown]
# # organizando a tabela

# %%
df = df[['IP', 'Data','hora', 'dia_semana', 'Metodo', 'URL', 'Protocolo', 'status_code', 'Tamanho',
       'User_Angent', 'Navegador', 'Versao_Navegador', 'Sistema_Operacional',
       'Versao', 'Dispositivo', 'E_Mobile', 'E_Tablet', 'E_PC', 'E_Bot',
       'status', 'Pais', 'Codigo_Pais', 'Regiao', 'Nome_Regiao', 'Cidade',
       'Latitude', 'Longitude', 'Fuso_Horario', 'ISP', 'Organizacao',
       'Sistema_Autonomo']]

# %% [markdown]
# # Passo4 - Métodos mais ultilizados /menos utilizados

# %%
#
s_a = df.URL.groupby(df.URL).count().sort_values(ascending=False)
print(f'O url mais acessado: {s_a.keys()[0]}\nNúmero de vezes:{s_a.values[0]}')
# Out:
# O url mais acessado: /filter
# Número de vezes:38

# %%
#
methodo_acsess_max = df.Metodo.groupby(df.Metodo).count().sort_values(ascending=False) # vendo o metodo mais acessado
methodo_acsess_min = df.Metodo.groupby(df.Metodo).count()[df.Metodo.groupby(df.Metodo).count() == df.Metodo.groupby(df.Metodo).count().min()] # vendo o metodo menos acessado
print(f'O método mais acessado é: {methodo_acsess_max.keys()[0]} --> Numero de vezes: {methodo_acsess_max.values[0]}')
print(f'O método menos acessado é: {methodo_acsess_min.keys()[0]} --> Numero de vezes: {methodo_acsess_min.values[0]}')
# Out:
# O método mais acessado é: GET --> Numero de vezes: 1486
# O método menos acessado é: HEAD --> Numero de vezes: 2

# %%
#Mostrando graficamente
metodos_http = df.Metodo.value_counts().reset_index()
metodos_http.columns = ['Métodos','Quantidade']
px.bar(metodos_http, x = 'Métodos', y ='Quantidade', color = 'Métodos', title = 'Uso de Métodos HTTP')
# df.Metodo.value_counts()

# %%
# 3 - IP que fez mais requisições
ip_req_max = df.IP.groupby(df.IP).count()[df.IP.groupby(df.IP).count() == df.IP.groupby(df.IP).count().max()] 
print(f'IP que fez mais requisições: {ip_req_max.keys()[0]}')
# Out:
# IP que fez mais requisições: 66.249.66.194

# %% [markdown]
# # Desitribuição por dispositivo

# %%
# # 4. Quantidade de requisições feita por cada dispositivo onde está com True
pc = df.E_PC.groupby(df.E_PC).count()[df.E_PC.groupby(df.E_PC).count() == df.E_PC.groupby(df.E_PC).count().min()] 
phone = df.E_Mobile.groupby(df.E_Mobile).count()[df.E_Mobile.groupby(df.E_Mobile).count() == df.E_Mobile.groupby(df.E_Mobile).count().min()]  
tablet = df.E_Tablet.groupby(df.E_Tablet).count()[df.E_Tablet.groupby(df.E_Tablet).count() == df.E_Tablet.groupby(df.E_Tablet).count().min()] 
bot = df.E_Bot.groupby(df.E_Bot).count()[df.E_Bot.groupby(df.E_Bot).count() == df.E_Bot.groupby(df.E_Bot).count().max()]


print(f'''Quantidade de requisições feita por cada dispositivo:
        Tablet: {tablet.values[0]};
        Telefone: {phone.values[0]};
        Pc: {pc.values[0]};
      
        ''')

dispositivos = ['Pc', 'Mobile', 'Tablet', 'Bot']
Quantidades = [pc.values[0], phone.values[0], tablet.values[0], bot.values[0]]
dic_dispositivos = {
 'Dispositivos': dispositivos,
 'Quantidade': Quantidades
}
df_dispositivos = pd.DataFrame(dic_dispositivos)
px.pie(df_dispositivos, values = 'Quantidade', names = 'Dispositivos', title = 'Distribuição por Dispositivos')
# Out:
# Quantidade de requisições feita por cada dispositivo:
#         Tablet: 100;
#         Telefone: 263;
#         Pc: 407;

# %%
# 5. Browser mais utilizado
brower_max = df.Navegador.groupby(df.Navegador).count()[df.Navegador.groupby(df.Navegador).count() == df.Navegador.groupby(df.Navegador).count().max()]  # brower mais usado
print(f'Browser mais utilizado: {brower_max.keys()[0]}')
# Out:
# Browser mais utilizado: Googlebot

# %%
navegadores_counts = df.Navegador.value_counts().reset_index().head(10)
navegadores_counts.columns = ['Navegador', 'Uso']
px.pie(navegadores_counts, values = 'Uso', names = 'Navegador', title='Top 10 dos Navegador usados', hole = 0.4)

# %%
# sistemas operacionais usados
s_o = df.Sistema_Operacional.value_counts().reset_index()
s_o.columns =['Sistemas Operacionais', 'Uso']
fig = px.bar(s_o, x = 'Sistemas Operacionais', y = 'Uso', color = 'Sistemas Operacionais', title = 'Sistemas Operacionais')
fig.show()

# %%
df.columns
# Out:
# Index(['IP', 'Data', 'hora', 'dia_semana', 'Metodo', 'URL', 'Protocolo',
#        'status_code', 'Tamanho', 'User_Angent', 'Navegador',
#        'Versao_Navegador', 'Sistema_Operacional', 'Versao', 'Dispositivo',
#        'E_Mobile', 'E_Tablet', 'E_PC', 'E_Bot', 'status', 'Pais',
#        'Codigo_Pais', 'Regiao', 'Nome_Regiao', 'Cidade', 'Latitude',
#        'Longitude', 'Fuso_Horario', 'ISP', 'Organizacao', 'Sistema_Autonomo'],
#       dtype='object')

# %%
#Mapa de Calor de Acessos
loc = df.groupby(['Pais','Latitude','Longitude']).size().reset_index(name = 'Acessos') # a ideia é saber quandas fezes os valores da latitude e da longitude aparecem no dataset
loc
# quantidade de ocorrências por coordenada
# Out:
#                Pais   Latitude  Longitude  Acessos
# 0            Canada  43.653200  -79.38320        1
# 1            France  48.974200    8.18510        6
# 2            France  50.692400    3.20113      121
# 3           Germany  49.452700   11.07830       90
# 4           Germany  50.116900    8.68370        2
# 5           Germany  50.384700    8.04750        1
# 6           Germany  50.477700   12.36490       13
# 7         Hong Kong  22.267000  114.18800        4
# 8              Iran  29.649500   52.47450        2
# 9              Iran  30.283200   57.07880        1
# 10             Iran  30.347300   48.29340        3
# 11             Iran  30.595900   50.24170        1
# 12             Iran  30.668200   51.58800        4
# 13             Iran  31.319000   48.68420        1
# 14             Iran  32.250100   54.01660        2
# 15             Iran  32.866300   59.22110        1
# 16             Iran  33.533900   48.32800        2
# 17             Iran  35.464100   53.20880        5
# 18             Iran  35.619400   51.47760        3
# 19             Iran  35.682400   51.41580        8
# 20             Iran  35.694400   51.42150        4
# 21             Iran  35.721900   51.33470       56
# 22             Iran  35.760700   51.40430       13
# 23             Iran  35.780800   51.43610        3
# 24             Iran  35.786300   51.38110      246
# 25             Iran  35.826200   50.97760        1
# 26             Iran  36.298100   59.60570        2
# 27             Iran  36.300600   59.59040        2
# 28          Ireland  53.349800   -6.26031       11
# 29          Romania  44.494600   26.05780        1
# 30     South Africa -25.877600   28.16820        1
# 31  The Netherlands  52.380300    4.64220       17
# 32    United States  26.359400  -80.07710       11
# 33    United States  36.677696  -78.37471       14
# 34    United States  37.332200 -122.01100       33
# 35    United States  37.388100 -121.87560        1
# 36    United States  37.422500 -122.08500      343
# 37    United States  39.043800  -77.48740        2
# 38    United States  40.551100  -74.46060       11
# 39    United States  40.602300  -75.47140      197
# 40    United States  45.526000 -122.98740        2
# 41    United States  47.233000 -119.85200      244
# 42    United States  47.490200 -122.30040        2

# %%
df.Pais.groupby(df.Pais).count()
# Out:
# Pais
# Canada               1
# France             127
# Germany            106
# Hong Kong            4
# Iran               360
# Ireland             11
# Romania              1
# South Africa         1
# The Netherlands     17
# United States      860
# Name: Pais, dtype: int64

# %%
fig_map = px.scatter_map(loc, lat='Latitude', 
                            lon='Longitude', 
                            size = 'Acessos', 
                            color = 'Acessos', 
                            title="Mapa de Calor de Acessos",
                            hover_name='Acessos',
                              zoom = 0,
                          
                            )
# fig_map.update_layout(margin={"r":0,"t":40,"l":0,"b":0})   
fig_map.show()

# %%
# Acessos por país
pais_Acess = df.value_counts('Pais').reset_index(name = 'Acessos')
# pais_Acess
fig_pa = px.bar(pais_Acess, x = 'Acessos',y = 'Pais',title = 'Acessos por Países')
fig_pa.update_yaxes(
    categoryorder="total ascending"
)
fig_pa

# %%
# IP mais ativos
top10_ip = df.value_counts('IP').reset_index(name = 'Requisições').head(10)
print('Top 10 dos Ips (clientes mais ativos)')
top10_ip
# Out:
# Top 10 dos Ips (clientes mais ativos)
#                IP  Requisições
# 0   66.249.66.194          327
# 1  130.185.74.243          246
# 2    66.249.66.91          197
# 3   207.46.13.136          104
# 4     91.99.72.15           90
# 5   207.46.13.104           86
# 6    17.58.102.43           32
# 7    5.123.174.57           24
# 8    5.160.157.20           21
# 9   157.55.39.175           20

# %%
df.head(3)
# Out:
#               IP                Data  hora   dia_semana Metodo  \
# 0   54.36.149.41 2019-01-22 03:56:14     3  Terça-feira    GET
# 1  40.77.167.129 2019-01-22 03:56:17     3  Terça-feira    GET
# 2    91.99.72.15 2019-01-22 03:56:17     3  Terça-feira    GET
#
#                                                  URL Protocolo  status_code  \
# 0     /filter/27-13-مگاپیکسل27-کمتر-از-5-مگاپیکسلp53  HTTP/1.1          200
# 1                  /image/14925/productmodel/100x100  HTTP/1.1          200
# 2  /product/31893/62100/سشوار-خانگی-پرنسلی-مدل-pr...  HTTP/1.1          200
#
#    Tamanho                                        User_Angent  Navegador  \
# 0    30577  Mozilla/5.0 (compatible; AhrefsBot/6.1; +http:...  AhrefsBot
# 1     1696  Mozilla/5.0 (compatible; bingbot/2.0; +http://...    bingbot
# 2    41483  Mozilla/5.0 (Windows NT 6.2; Win64; x64; rv:16...    Firefox
#
#   Versao_Navegador Sistema_Operacional     Versao Dispositivo  E_Mobile  \
# 0              6.1               Other  Not Found      Spider     False
# 1              2.0               Other  Not Found      Spider     False
# 2             16.0             Windows          8       Other     False
#
#    E_Tablet   E_PC  E_Bot   status           Pais Codigo_Pais Regiao  \
# 0     False  False   True  success         France          FR    HDF
# 1     False  False   True  success  United States          US     VA
# 2     False   True  False  success        Germany          DE     BY
#
#        Nome_Regiao     Cidade   Latitude  Longitude      Fuso_Horario  \
# 0  Hauts-de-France    Roubaix  50.692400    3.20113      Europe/Paris
# 1         Virginia    Boydton  36.677696  -78.37471  America/New_York
# 2          Bavaria  Nuremberg  49.452700   11.07830     Europe/Berlin
#
#                      ISP                      Organizacao  \
# 0                OVH SAS                              OVH
# 1  Microsoft Corporation  Microsoft Azure Cloud (eastus2)
# 2    Hetzner Online GmbH                          Hetzner
#
#                Sistema_Autonomo
# 0               AS16276 OVH SAS
# 1  AS8075 Microsoft Corporation
# 2   AS24940 Hetzner Online GmbH
